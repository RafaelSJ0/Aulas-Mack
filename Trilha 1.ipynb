# %% [markdown]
# Foi escolhido um texto em inglês, ele mostra como é uma apresentação pessoal a outra pessoa, e como se deve apresentar em uma outra lingua, coisas frequentes de seu cotidiano.

# %% [markdown]
# Aquisição dos Dados.
# Realizei a aquisição através de um site que ministra curso, porém ao importar o conteúdo não consegui deixar de fora a formatação HTML, ela atrapalhou muito o gráfico final, tentei importar local e não tve sucesso, tentei outras biblioecas e também não obtive exito, assim comclui, mas ainda estou pesquisando outra forma de subir somente o .TXT e melhorar o resultado.

# %%
import urllib.request  

texto = []

for line in urllib.request.urlopen('https://lingua.com/pt/ingles/leitura/john/'): 
    texto.append(line.decode('utf-8'))

# f = open('/kate_beckinsale.txt','r')    # para arquivos locais
# for line in f:
#    texto.append(line)

for i in range(len(texto)):
    texto[i] = texto[i].lower() # para unicidade
    texto[i] = texto[i].replace('\n','')
    texto[i] = texto[i].replace('.','')
    texto[i] = texto[i].replace(',','')
    texto[i] = texto[i].replace('(','')
    texto[i] = texto[i].replace(')','')
    texto[i] = texto[i].replace('?','')
    texto[i] = texto[i].replace('\'','') # elimina ' e "

# %% [markdown]
# Construção do Dicionário

# %%
mydict = {}                             # crie um dicionário vazio

for line in texto:

  line = line.lower()                   # converte para lower
  words = line.split()                  # separa cada palavra
#  print(words)

  for word in words:                      # para cada palavra em words
    if word not in mydict.keys():         # se palavra não está no dicionário 
      mydict[word] = 1                    # acrescenta a word com o valor 1
    else:                                 # se a entrada já existe 
      mydict[word] =  mydict[word] + 1    # apenas soma 1 ao valor já existente

print(mydict)
# Out:
# {'<!doctype': 1, 'html>': 1, '<html': 1, 'lang="pt">': 1, '<head>': 1, '<meta': 5, 'http-equiv="content-type"': 1, 'content="text/html;': 1, 'charset=utf-8"': 1, '/>': 10, 'name="viewport"': 1, 'content="width=device-width': 1, 'initial-scale=1': 1, 'maximum-scale=1">': 1, '<title>my': 1, 'name': 3, 'is': 8, 'john': 8, '-': 5, 'texto': 2, 'em': 1, 'inglês</title>': 1, 'name="author"': 1, 'content="tim': 1, 'seeger">': 1, '<link': 17, 'href="https://linguacom/pt/ingles/leitura/john/"': 2, 'rel="canonical"><meta': 1, 'name="robots"': 1, 'content="indexfollow"><meta': 1, 'name="language"': 1, 'content="pt">': 1, 'rel="alternate"': 9, 'hreflang="en"': 1, 'href="https://linguacom/english/reading/john/"': 1, 'hreflang="de"': 1, 'href="https://linguacom/de/englisch/lesen/john/"': 1, 'hreflang="fr"': 1, 'href="https://linguacom/fr/anglais/lecture/john/"': 1, 'hreflang="es"': 1, 'href="https://linguacom/es/ingles/lectura/john/"': 1, 'hreflang="pl"': 1, 'href="https://linguacom/pl/angielski/cz
# ...

# %% [markdown]
# Exibição dos Resultados

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

df = pd.DataFrame(mydict.items(),  columns=['word', 'count']).sort_values('count',ascending=False)
df = df[df['count'] > 4] # somente termos com mais de 4 ocorrências
# df = df.iloc[ np.int(len(df)/2) - 10 : np.int(len(df)/2) + 10 ] # para livros ou textos com muitos termos limita a um número mínimo de termos

plt.figure(figsize=(24,10))
mpl.style.use(['seaborn'])
sns.barplot(x=df.word,y=df['count'])
plt.xticks(rotation=90) 

plt.show()

# %% [markdown]
# Gostei da primeira experiência com a aplicação, foi um pouco complicado entender as funções, mas no final cheguei a um bom resultado, não obtive exito em subir somente os textos, mas logo, conseguirei importar e subir somente o nescessário.
